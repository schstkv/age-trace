# %%
import pandas as pd
import numpy as np
import util
import yaml
import tensorflow as tf
from trace_plotting import plot_two_traces
import os
import time

os.environ["CUDA_VISIBLE_DEVICES"]="1" #model will be trained on GPU 1
data_path = 'data'

# %%
# Load data
train = np.load(data_path + '/ae_training_1mil.npy').astype(np.float32)
own_set = np.load(data_path + '/own_set_1mil.npy').astype(np.float32)
other_set = np.load(data_path + '/other_set_1mil.npy').astype(np.float32)

# Test Set is used to validate AE on
test =other_set

# %%
#data = np.load(data_path + '/traces_266517.npy')
#train_size = data.shape[0] - int(data.shape[0]/3)
#train = data[:train_size].astype(np.float32)
#test = data[train_size:].astype(np.float32)

# %%
print("Train size: " + str(train.shape[0]))
print("own_set size: " + str(own_set.shape[0]))
print("other_set size: " + str(other_set.shape[0]))
# Out:
# Train size: 2566
# own_set size: 517
# other_set size: 2161

# %%
# Definition of Model
class AE(tf.keras.Model):
    def __init__(self, batch_size, timesteps, feats_size, latent_dim=50):
        super(AE, self).__init__()
        self.latent_dim = latent_dim

        self._batch_size = batch_size
        self._timesteps  = timesteps
        self._feats_size = feats_size

        self.encoder = tf.keras.Sequential(
            [
                # Input data shape: (batch_size, 256, 3)
                tf.keras.layers.InputLayer(input_shape=(self._timesteps, self._feats_size)),
                tf.keras.layers.Flatten(),
                tf.keras.layers.Dense(units = self._timesteps * self._feats_size, activation=tf.nn.relu),
                #tf.keras.layers.Dense(units= self._timesteps * self._feats_size, activation=tf.nn.relu),
                # No activation
                tf.keras.layers.Dense(latent_dim),
                
            ]
        )

        self.decoder = tf.keras.Sequential(
            [
                tf.keras.layers.InputLayer(input_shape=(latent_dim,)),
                tf.keras.layers.Dense(units=self._timesteps * self._feats_size, activation=tf.nn.relu),
                tf.keras.layers.Dense(units=self._timesteps * self._feats_size, activation=None),
                tf.keras.layers.Reshape(target_shape=(self._timesteps, self._feats_size)),
            ]
        )


    def run_model(self, x):
        s = self.encoder(x)
        x_recon = self.decoder(s)
        return s, x_recon

    def compute_loss(self, x):
        s, x_recon = self.run_model(x)
        # Simple Squered Diff
        cost = tf.math.reduce_mean(tf.square(tf.subtract(x_recon, x)))
        return cost
    
    #Training and Test Step
    @tf.function
    def train_step(self, x, optimizer):
        """Executes one training step and returns the loss.

        This function computes the loss and gradients, and uses the latter to
        update the model's parameters.
        """
        with tf.GradientTape() as tape:
            loss = self.compute_loss(x)
        gradients = tape.gradient(loss, self.trainable_variables)
        optimizer.apply_gradients(zip(gradients, self.trainable_variables))
        return loss

    @tf.function
    def test_step(self, x):
        # training=False is only needed if there are layers with different
        # behavior during training versus inference (e.g. Dropout).

        t_loss =  self.compute_loss(x)
        return t_loss

# %%
# Train Model

batch_size = 256
timesteps = train.shape[1]
feats_len = train.shape[2]

# Create an instance of the model
model = AE(batch_size, timesteps, feats_len)
optimizer = tf.keras.optimizers.Adam(1e-4)

# Use tf.data for Data handling 
batch_size = 256
dataset = tf.data.Dataset.from_tensor_slices(train)
dataset = dataset.shuffle(len(train), reshuffle_each_iteration=True)
# Create Batches from dataset
# Drop remainder: Drops the last Batch, as it has not the same shape as the other batches
#dataset  = dataset.batch(batch_size, drop_remainder  = True)
dataset  = dataset.batch(batch_size)
dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)



EPOCHS = 1000
num_samples = len(train)
start = time.time()
for epoch in range(EPOCHS):
    
    next_batch_start = 0
    idx_end = 0
    # Iterate Batches
    for batch in dataset:
        # Train step with optimization
        loss = model.train_step(batch, optimizer)

    test_loss = model.test_step(test)

    template = 'Epoch {:3d}, Loss: {:.4f}, Test Loss: {:.4f}'
    print(template.format(epoch + 1,loss.numpy(),test_loss.numpy()))

    # s, x_recon = model.run_model(test)
    # print(test[0, 0:10])
    # print(s[0, 0:10])
    # print(x_recon[0, 0:10])
    
end = time.time()
print("Training duration: {}".format(end - start))
s, x_recon = model.run_model(test)


print(test[0, 0:10])
print(s[0, 0:10].numpy())
print(x_recon[0, 0:10].numpy())
# Out:
# Epoch   1, Loss: 758.9424, Test Loss: 734.8417
# Epoch   2, Loss: 410.5894, Test Loss: 378.4577
# Epoch   3, Loss: 142.5995, Test Loss: 128.0090
# Epoch   4, Loss: 35.2017, Test Loss: 30.9736
# Epoch   5, Loss: 7.6767, Test Loss: 6.8123
# Epoch   6, Loss: 2.3731, Test Loss: 2.1658
# Epoch   7, Loss: 1.3522, Test Loss: 1.1060
# Epoch   8, Loss: 0.5597, Test Loss: 0.5860
# Epoch   9, Loss: 0.4397, Test Loss: 0.4172
# Epoch  10, Loss: 0.5437, Test Loss: 0.3717
# Epoch  11, Loss: 0.5844, Test Loss: 0.3547
# Epoch  12, Loss: 0.2312, Test Loss: 0.3509
# Epoch  13, Loss: 0.5046, Test Loss: 0.3473
# Epoch  14, Loss: 0.1190, Test Loss: 0.3444
# Epoch  15, Loss: 0.2751, Test Loss: 0.3427
# Epoch  16, Loss: 0.3757, Test Loss: 0.3416
# Epoch  17, Loss: 0.5677, Test Loss: 0.3408
# Epoch  18, Loss: 0.4081, Test Loss: 0.3397
# Epoch  19, Loss: 0.3739, Test Loss: 0.3398
# Epoch  20, Loss: 0.3792, Test Loss: 0.3384
# Epoch  21, Loss: 0.3226, Test Loss: 0.3375
# Epoch  22, Loss: 0.5519, Test Loss: 0.3369
# Epoch  23, Loss: 0.4680, Test Loss: 0.3382
# Epoch  24, Loss: 0.3002, Test Loss: 0.3385
# Epoch  25, Loss: 0.4092, Test Loss: 0.3347
# Epoch  26, Loss: 0.1932, Test Loss: 0.3318
# Epoch  27, Loss: 0.7004, Test Loss: 0.3313
# Epoch  28, Loss: 0.5006, Test Loss: 0.3290
# Epoch  29, Loss: 0.3339, Test Loss: 0.3275
# Epoch  30, Loss: 0.2490, Test Loss: 0.3278
# Epoch  31, Loss: 0.5794, Test Loss: 0.3304
# Epoch  32, Loss: 0.3563, Test Loss: 0.3373
# Epoch  33, Loss: 0.3592, Test Loss: 0.3269
# Epoch  34, Loss: 0.3579, Test Loss: 0.3245
# Epoch  35, Loss: 0.4632, Test Loss: 0.3211
# Epoch  36, Loss: 0.2125, Test Loss: 0.3201
# Epoch  37, Loss: 0.4674, Test Loss: 0.3180
# Epoch  38, Loss: 0.3908, Test Loss: 0.3189
# Epoch  39, Loss: 0.2933, Test Loss: 0.3187
# Epoch  40, Loss: 0.6378, Test Loss: 0.3178
# Epoch  41, Loss: 0.2518, Test Loss: 0.3204
# Epoch  42, Loss: 0.2931, Test Loss: 0.3146
# Epoch  43, Loss: 0.3549, Test Loss: 0.3142
# Epoch  44, Loss: 0.2736, Test Loss: 0.3195
# Epoch  45, Loss: 0.3545, Test Loss: 0.3163
# Epoch  46, Loss: 0.3070, Test Loss: 0.3147
# Epoch  47, Loss: 0.3115, Test Loss: 0.3107
# Epoch  48, Loss: 0.3539, Test Loss: 0.3190
# Epoch  49, Loss: 0.5699, Test Loss: 0.3170
# Epoch  50, Loss: 0.2876, Test Loss: 0.3087
# Epoch  51, Loss: 0.3344, Test Loss: 0.3063
# Epoch  52, Loss: 0.4012, Test Loss: 0.3041
# Epoch  53, Loss: 0.2930, Test Loss: 0.3148
# Epoch  54, Loss: 0.1698, Test Loss: 0.3051
# Epoch  55, Loss: 0.2395, Test Loss: 0.3052
# Epoch  56, Loss: 0.2454, Test Loss: 0.3017
# Epoch  57, Loss: 0.2707, Test Loss: 0.3014
# Epoch  58, Loss: 0.5228, Test Loss: 0.3040
# Epoch  59, Loss: 0.1275, Test Loss: 0.3016
# Epoch  60, Loss: 0.2931, Test Loss: 0.2982
# Epoch  61, Loss: 0.2866, Test Loss: 0.3004
# Epoch  62, Loss: 0.1604, Test Loss: 0.2988
# Epoch  63, Loss: 0.1718, Test Loss: 0.2954
# Epoch  64, Loss: 0.5111, Test Loss: 0.3087
# Epoch  65, Loss: 0.3674, Test Loss: 0.3042
# Epoch  66, Loss: 0.3924, Test Loss: 0.2943
# Epoch  67, Loss: 0.1902, Test Loss: 0.2918
# Epoch  68, Loss: 0.2429, Test Loss: 0.2936
# Epoch  69, Loss: 0.2760, Test Loss: 0.2899
# Epoch  70, Loss: 0.2027, Test Loss: 0.2880
# Epoch  71, Loss: 0.3163, Test Loss: 0.2877
# Epoch  72, Loss: 0.2537, Test Loss: 0.2889
# Epoch  73, Loss: 0.1385, Test Loss: 0.2863
# Epoch  74, Loss: 0.2407, Test Loss: 0.2862
# Epoch  75, Loss: 0.2782, Test Loss: 0.2867
# Epoch  76, Loss: 0.5290, Test Loss: 0.2881
# Epoch  77, Loss: 0.5467, Test Loss: 0.2864
# Epoch  78, Loss: 0.3681, Test Loss: 0.2838
# Epoch  79, Loss: 0.1119, Test Loss: 0.2798
# Epoch  80, Loss: 0.2606, Test Loss: 0.2812
# Epoch  81, Loss: 0.2017, Test Loss: 0.2811
# Epoch  82, Loss: 0.1471, Test Loss: 0.2793
# Epoch  83, Loss: 0.2440, Test Loss: 0.2767
# Epoch  84, Loss: 0.1491, Test Loss: 0.2791
# Epoch  85, Loss: 0.1744, Test Loss: 0.2738
# Epoch  86, Loss: 0.2028, Test Loss: 0.2727
# Epoch  87, Loss: 0.1782, Test Loss: 0.2705
# Epoch  88, Loss: 0.2116, Test Loss: 0.2697
# Epoch  89, Loss: 0.3848, Test Loss: 0.2724
# Epoch  90, Loss: 0.3376, Test Loss: 0.2687
# Epoch  91, Loss: 0.2334, Test Loss: 0.2705
# Epoch  92, Loss: 0.3447, Test Loss: 0.2719
# Epoch  93, Loss: 0.2817, Test Loss: 0.2726
# Epoch  94, Loss: 0.2691, Test Loss: 0.2707
# Epoch  95, Loss: 0.1509, Test Loss: 0.2623
# Epoch  96, Loss: 0.1707, Test Loss: 0.2583
# Epoch  97, Loss: 0.1644, Test Loss: 0.2562
# Epoch  98, Loss: 0.1746, Test Loss: 0.2534
# Epoch  99, Loss: 0.2496, Test Loss: 0.2575
# Epoch 100, Loss: 0.1317, Test Loss: 0.2559
# Epoch 101, Loss: 0.1353, Test Loss: 0.2510
# Epoch 102, Loss: 0.2035, Test Loss: 0.2485
# Epoch 103, Loss: 0.2580, Test Loss: 0.2447
# Epoch 104, Loss: 0.2667, Test Loss: 0.2423
# Epoch 105, Loss: 0.2896, Test Loss: 0.2401
# Epoch 106, Loss: 0.1557, Test Loss: 0.2398
# Epoch 107, Loss: 0.2336, Test Loss: 0.2397
# Epoch 108, Loss: 0.2322, Test Loss: 0.2415
# Epoch 109, Loss: 0.3597, Test Loss: 0.2361
# Epoch 110, Loss: 0.1812, Test Loss: 0.2277
# Epoch 111, Loss: 0.1554, Test Loss: 0.2263
# Epoch 112, Loss: 0.2428, Test Loss: 0.2220
# Epoch 113, Loss: 0.1024, Test Loss: 0.2208
# Epoch 114, Loss: 0.2584, Test Loss: 0.2176
# Epoch 115, Loss: 0.2097, Test Loss: 0.2126
# Epoch 116, Loss: 0.1884, Test Loss: 0.2106
# Epoch 117, Loss: 0.2327, Test Loss: 0.2070
# Epoch 118, Loss: 0.2006, Test Loss: 0.2181
# Epoch 119, Loss: 0.1572, Test Loss: 0.2085
# Epoch 120, Loss: 0.2120, Test Loss: 0.2008
# Epoch 121, Loss: 0.2150, Test Loss: 0.1923
# Epoch 122, Loss: 0.1449, Test Loss: 0.1973
# Epoch 123, Loss: 0.0928, Test Loss: 0.1871
# Epoch 124, Loss: 0.2663, Test Loss: 0.1827
# Epoch 125, Loss: 0.1477, Test Loss: 0.1801
# Epoch 126, Loss: 0.1264, Test Loss: 0.1752
# Epoch 127, Loss: 0.1588, Test Loss: 0.1742
# Epoch 128, Loss: 0.3593, Test Loss: 0.1904
# Epoch 129, Loss: 0.1952, Test Loss: 0.1710
# Epoch 130, Loss: 0.1557, Test Loss: 0.1623
# Epoch 131, Loss: 0.2026, Test Loss: 0.1553
# Epoch 132, Loss: 0.1181, Test Loss: 0.1519
# Epoch 133, Loss: 0.2676, Test Loss: 0.1487
# Epoch 134, Loss: 0.1339, Test Loss: 0.1409
# Epoch 135, Loss: 0.1421, Test Loss: 0.1364
# Epoch 136, Loss: 0.1164, Test Loss: 0.1406
# Epoch 137, Loss: 0.1346, Test Loss: 0.1402
# Epoch 138, Loss: 0.0809, Test Loss: 0.1292
# Epoch 139, Loss: 0.1278, Test Loss: 0.1235
# Epoch 140, Loss: 0.1383, Test Loss: 0.1196
# Epoch 141, Loss: 0.1011, Test Loss: 0.1169
# Epoch 142, Loss: 0.1249, Test Loss: 0.1122
# Epoch 143, Loss: 0.0638, Test Loss: 0.1117
# Epoch 144, Loss: 0.1043, Test Loss: 0.1078
# Epoch 145, Loss: 0.1349, Test Loss: 0.1059
# Epoch 146, Loss: 0.0775, Test Loss: 0.1002
# Epoch 147, Loss: 0.1124, Test Loss: 0.0996
# Epoch 148, Loss: 0.0950, Test Loss: 0.0977
# Epoch 149, Loss: 0.0620, Test Loss: 0.0949
# Epoch 150, Loss: 0.1218, Test Loss: 0.0954
# Epoch 151, Loss: 0.0730, Test Loss: 0.0896
# Epoch 152, Loss: 0.1180, Test Loss: 0.0909
# Epoch 153, Loss: 0.0547, Test Loss: 0.0877
# Epoch 154, Loss: 0.0690, Test Loss: 0.0859
# Epoch 155, Loss: 0.0928, Test Loss: 0.0814
# Epoch 156, Loss: 0.0430, Test Loss: 0.0798
# Epoch 157, Loss: 0.1044, Test Loss: 0.0771
# Epoch 158, Loss: 0.0630, Test Loss: 0.0780
# Epoch 159, Loss: 0.1016, Test Loss: 0.0837
# Epoch 160, Loss: 0.0589, Test Loss: 0.0754
# Epoch 161, Loss: 0.0876, Test Loss: 0.0736
# Epoch 162, Loss: 0.1612, Test Loss: 0.0761
# Epoch 163, Loss: 0.0548, Test Loss: 0.0740
# Epoch 164, Loss: 0.0614, Test Loss: 0.0751
# Epoch 165, Loss: 0.0714, Test Loss: 0.0694
# Epoch 166, Loss: 0.0843, Test Loss: 0.0662
# Epoch 167, Loss: 0.0965, Test Loss: 0.0687
# Epoch 168, Loss: 0.0545, Test Loss: 0.0713
# Epoch 169, Loss: 0.0762, Test Loss: 0.0646
# Epoch 170, Loss: 0.0557, Test Loss: 0.0649
# Epoch 171, Loss: 0.0761, Test Loss: 0.0656
# Epoch 172, Loss: 0.0612, Test Loss: 0.0646
# Epoch 173, Loss: 0.0784, Test Loss: 0.0618
# Epoch 174, Loss: 0.0826, Test Loss: 0.0613
# Epoch 175, Loss: 0.0525, Test Loss: 0.0591
# Epoch 176, Loss: 0.0671, Test Loss: 0.0609
# Epoch 177, Loss: 0.0584, Test Loss: 0.0602
# Epoch 178, Loss: 0.0480, Test Loss: 0.0632
# Epoch 179, Loss: 0.0552, Test Loss: 0.0580
# Epoch 180, Loss: 0.0295, Test Loss: 0.0592
# Epoch 181, Loss: 0.0435, Test Loss: 0.0562
# Epoch 182, Loss: 0.0627, Test Loss: 0.0601
# Epoch 183, Loss: 0.0800, Test Loss: 0.0588
# Epoch 184, Loss: 0.1030, Test Loss: 0.0591
# Epoch 185, Loss: 0.0681, Test Loss: 0.0559
# Epoch 186, Loss: 0.0250, Test Loss: 0.0539
# Epoch 187, Loss: 0.0474, Test Loss: 0.0559
# Epoch 188, Loss: 0.0399, Test Loss: 0.0541
# Epoch 189, Loss: 0.0459, Test Loss: 0.0530
# Epoch 190, Loss: 0.0542, Test Loss: 0.0526
# Epoch 191, Loss: 0.0970, Test Loss: 0.0558
# Epoch 192, Loss: 0.0674, Test Loss: 0.0563
# Epoch 193, Loss: 0.0565, Test Loss: 0.0539
# Epoch 194, Loss: 0.0477, Test Loss: 0.0532
# Epoch 195, Loss: 0.0933, Test Loss: 0.0533
# Epoch 196, Loss: 0.0512, Test Loss: 0.0529
# Epoch 197, Loss: 0.0495, Test Loss: 0.0514
# Epoch 198, Loss: 0.0540, Test Loss: 0.0534
# Epoch 199, Loss: 0.0378, Test Loss: 0.0508
# Epoch 200, Loss: 0.0697, Test Loss: 0.0526
# Epoch 201, Loss: 0.0286, Test Loss: 0.0522
# Epoch 202, Loss: 0.0247, Test Loss: 0.0499
# Epoch 203, Loss: 0.0371, Test Loss: 0.0499
# Epoch 204, Loss: 0.0303, Test Loss: 0.0496
# Epoch 205, Loss: 0.0814, Test Loss: 0.0505
# Epoch 206, Loss: 0.0731, Test Loss: 0.0519
# Epoch 207, Loss: 0.0524, Test Loss: 0.0504
# Epoch 208, Loss: 0.0222, Test Loss: 0.0495
# Epoch 209, Loss: 0.0465, Test Loss: 0.0500
# Epoch 210, Loss: 0.0428, Test Loss: 0.0549
# Epoch 211, Loss: 0.0502, Test Loss: 0.0497
# Epoch 212, Loss: 0.0256, Test Loss: 0.0482
# Epoch 213, Loss: 0.0567, Test Loss: 0.0512
# Epoch 214, Loss: 0.1020, Test Loss: 0.0506
# Epoch 215, Loss: 0.0356, Test Loss: 0.0486
# Epoch 216, Loss: 0.0532, Test Loss: 0.0516
# Epoch 217, Loss: 0.0246, Test Loss: 0.0489
# Epoch 218, Loss: 0.0288, Test Loss: 0.0470
# Epoch 219, Loss: 0.0363, Test Loss: 0.0482
# Epoch 220, Loss: 0.0437, Test Loss: 0.0478
# Epoch 221, Loss: 0.0683, Test Loss: 0.0503
# Epoch 222, Loss: 0.0443, Test Loss: 0.0494
# Epoch 223, Loss: 0.0490, Test Loss: 0.0503
# Epoch 224, Loss: 0.1354, Test Loss: 0.0501
# Epoch 225, Loss: 0.0218, Test Loss: 0.0472
# Epoch 226, Loss: 0.0266, Test Loss: 0.0541
# Epoch 227, Loss: 0.0436, Test Loss: 0.0495
# Epoch 228, Loss: 0.0293, Test Loss: 0.0493
# Epoch 229, Loss: 0.0112, Test Loss: 0.0484
# Epoch 230, Loss: 0.0802, Test Loss: 0.0525
# Epoch 231, Loss: 0.0753, Test Loss: 0.0500
# Epoch 232, Loss: 0.0399, Test Loss: 0.0500
# Epoch 233, Loss: 0.0265, Test Loss: 0.0477
# Epoch 234, Loss: 0.0370, Test Loss: 0.0467
# Epoch 235, Loss: 0.0276, Test Loss: 0.0454
# Epoch 236, Loss: 0.0389, Test Loss: 0.0461
# Epoch 237, Loss: 0.0273, Test Loss: 0.0469
# Epoch 238, Loss: 0.0539, Test Loss: 0.0497
# Epoch 239, Loss: 0.0368, Test Loss: 0.0481
# Epoch 240, Loss: 0.0742, Test Loss: 0.0497
# Epoch 241, Loss: 0.0314, Test Loss: 0.0479
# Epoch 242, Loss: 0.0397, Test Loss: 0.0511
# Epoch 243, Loss: 0.0721, Test Loss: 0.0513
# Epoch 244, Loss: 0.0790, Test Loss: 0.0465
# Epoch 245, Loss: 0.0562, Test Loss: 0.0461
# Epoch 246, Loss: 0.0335, Test Loss: 0.0460
# Epoch 247, Loss: 0.0288, Test Loss: 0.0468
# Epoch 248, Loss: 0.0709, Test Loss: 0.0481
# Epoch 249, Loss: 0.0364, Test Loss: 0.0513
# Epoch 250, Loss: 0.0384, Test Loss: 0.0473
# Epoch 251, Loss: 0.0894, Test Loss: 0.0489
# Epoch 252, Loss: 0.0355, Test Loss: 0.0460
# Epoch 253, Loss: 0.0505, Test Loss: 0.0479
# Epoch 254, Loss: 0.0543, Test Loss: 0.0492
# Epoch 255, Loss: 0.0206, Test Loss: 0.0451
# Epoch 256, Loss: 0.0498, Test Loss: 0.0501
# Epoch 257, Loss: 0.0275, Test Loss: 0.0467
# Epoch 258, Loss: 0.0211, Test Loss: 0.0470
# Epoch 259, Loss: 0.0676, Test Loss: 0.0487
# Epoch 260, Loss: 0.0501, Test Loss: 0.0466
# Epoch 261, Loss: 0.0438, Test Loss: 0.0442
# Epoch 262, Loss: 0.0475, Test Loss: 0.0454
# Epoch 263, Loss: 0.0551, Test Loss: 0.0490
# Epoch 264, Loss: 0.0848, Test Loss: 0.0519
# Epoch 265, Loss: 0.0343, Test Loss: 0.0492
# Epoch 266, Loss: 0.0449, Test Loss: 0.0474
# Epoch 267, Loss: 0.0240, Test Loss: 0.0440
# Epoch 268, Loss: 0.0299, Test Loss: 0.0455
# Epoch 269, Loss: 0.0366, Test Loss: 0.0467
# Epoch 270, Loss: 0.0673, Test Loss: 0.0480
# Epoch 271, Loss: 0.0371, Test Loss: 0.0495
# Epoch 272, Loss: 0.0603, Test Loss: 0.0445
# Epoch 273, Loss: 0.0538, Test Loss: 0.0430
# Epoch 274, Loss: 0.0257, Test Loss: 0.0420
# Epoch 275, Loss: 0.0310, Test Loss: 0.0475
# Epoch 276, Loss: 0.0960, Test Loss: 0.0501
# Epoch 277, Loss: 0.0317, Test Loss: 0.0445
# Epoch 278, Loss: 0.0267, Test Loss: 0.0424
# Epoch 279, Loss: 0.0315, Test Loss: 0.0457
# Epoch 280, Loss: 0.0329, Test Loss: 0.0442
# Epoch 281, Loss: 0.0994, Test Loss: 0.0486
# Epoch 282, Loss: 0.0298, Test Loss: 0.0449
# Epoch 283, Loss: 0.0246, Test Loss: 0.0424
# Epoch 284, Loss: 0.0393, Test Loss: 0.0422
# Epoch 285, Loss: 0.0409, Test Loss: 0.0424
# Epoch 286, Loss: 0.0336, Test Loss: 0.0413
# Epoch 287, Loss: 0.1401, Test Loss: 0.0596
# Epoch 288, Loss: 0.0319, Test Loss: 0.0496
# Epoch 289, Loss: 0.0446, Test Loss: 0.0484
# Epoch 290, Loss: 0.0417, Test Loss: 0.0443
# Epoch 291, Loss: 0.0521, Test Loss: 0.0455
# Epoch 292, Loss: 0.0473, Test Loss: 0.0440
# Epoch 293, Loss: 0.0292, Test Loss: 0.0443
# Epoch 294, Loss: 0.0648, Test Loss: 0.0440
# Epoch 295, Loss: 0.0847, Test Loss: 0.0526
# Epoch 296, Loss: 0.0500, Test Loss: 0.0441
# Epoch 297, Loss: 0.0185, Test Loss: 0.0408
# Epoch 298, Loss: 0.0150, Test Loss: 0.0407
# Epoch 299, Loss: 0.1092, Test Loss: 0.0516
# Epoch 300, Loss: 0.0286, Test Loss: 0.0434
# Epoch 301, Loss: 0.0552, Test Loss: 0.0450
# Epoch 302, Loss: 0.0377, Test Loss: 0.0439
# Epoch 303, Loss: 0.0642, Test Loss: 0.0465
# Epoch 304, Loss: 0.0877, Test Loss: 0.0546
# Epoch 305, Loss: 0.0314, Test Loss: 0.0440
# Epoch 306, Loss: 0.0663, Test Loss: 0.0439
# Epoch 307, Loss: 0.0480, Test Loss: 0.0464
# Epoch 308, Loss: 0.0177, Test Loss: 0.0415
# Epoch 309, Loss: 0.0365, Test Loss: 0.0462
# Epoch 310, Loss: 0.0883, Test Loss: 0.0485
# Epoch 311, Loss: 0.0355, Test Loss: 0.0446
# Epoch 312, Loss: 0.0710, Test Loss: 0.0447
# Epoch 313, Loss: 0.0421, Test Loss: 0.0478
# Epoch 314, Loss: 0.0412, Test Loss: 0.0423
# Epoch 315, Loss: 0.0342, Test Loss: 0.0430
# Epoch 316, Loss: 0.0258, Test Loss: 0.0431
# Epoch 317, Loss: 0.0209, Test Loss: 0.0401
# Epoch 318, Loss: 0.0365, Test Loss: 0.0396
# Epoch 319, Loss: 0.0479, Test Loss: 0.0417
# Epoch 320, Loss: 0.0198, Test Loss: 0.0406
# Epoch 321, Loss: 0.0234, Test Loss: 0.0388
# Epoch 322, Loss: 0.0883, Test Loss: 0.0492
# Epoch 323, Loss: 0.0253, Test Loss: 0.0433
# Epoch 324, Loss: 0.0644, Test Loss: 0.0507
# Epoch 325, Loss: 0.0358, Test Loss: 0.0418
# Epoch 326, Loss: 0.0163, Test Loss: 0.0399
# Epoch 327, Loss: 0.1747, Test Loss: 0.0477
# Epoch 328, Loss: 0.0289, Test Loss: 0.0421
# Epoch 329, Loss: 0.0449, Test Loss: 0.0401
# Epoch 330, Loss: 0.0173, Test Loss: 0.0384
# Epoch 331, Loss: 0.0665, Test Loss: 0.0442
# Epoch 332, Loss: 0.0724, Test Loss: 0.0420
# Epoch 333, Loss: 0.0312, Test Loss: 0.0418
# Epoch 334, Loss: 0.0471, Test Loss: 0.0387
# Epoch 335, Loss: 0.0536, Test Loss: 0.0489
# Epoch 336, Loss: 0.0256, Test Loss: 0.0406
# Epoch 337, Loss: 0.0487, Test Loss: 0.0443
# Epoch 338, Loss: 0.0598, Test Loss: 0.0431
# Epoch 339, Loss: 0.0328, Test Loss: 0.0433
# Epoch 340, Loss: 0.0266, Test Loss: 0.0411
# Epoch 341, Loss: 0.0717, Test Loss: 0.0452
# Epoch 342, Loss: 0.0666, Test Loss: 0.0413
# Epoch 343, Loss: 0.0483, Test Loss: 0.0394
# Epoch 344, Loss: 0.0208, Test Loss: 0.0394
# Epoch 345, Loss: 0.0327, Test Loss: 0.0389
# Epoch 346, Loss: 0.0357, Test Loss: 0.0385
# Epoch 347, Loss: 0.0268, Test Loss: 0.0409
# Epoch 348, Loss: 0.0660, Test Loss: 0.0469
# Epoch 349, Loss: 0.0476, Test Loss: 0.0453
# Epoch 350, Loss: 0.0381, Test Loss: 0.0422
# Epoch 351, Loss: 0.0203, Test Loss: 0.0383
# Epoch 352, Loss: 0.0499, Test Loss: 0.0413
# Epoch 353, Loss: 0.0268, Test Loss: 0.0391
# Epoch 354, Loss: 0.0210, Test Loss: 0.0388
# Epoch 355, Loss: 0.0444, Test Loss: 0.0516
# Epoch 356, Loss: 0.0992, Test Loss: 0.0499
# Epoch 357, Loss: 0.1035, Test Loss: 0.0533
# Epoch 358, Loss: 0.0304, Test Loss: 0.0413
# Epoch 359, Loss: 0.0320, Test Loss: 0.0394
# Epoch 360, Loss: 0.0682, Test Loss: 0.0391
# Epoch 361, Loss: 0.0245, Test Loss: 0.0410
# Epoch 362, Loss: 0.0750, Test Loss: 0.0410
# Epoch 363, Loss: 0.0733, Test Loss: 0.0470
# Epoch 364, Loss: 0.0511, Test Loss: 0.0409
# Epoch 365, Loss: 0.0363, Test Loss: 0.0408
# Epoch 366, Loss: 0.0260, Test Loss: 0.0372
# Epoch 367, Loss: 0.0204, Test Loss: 0.0369
# Epoch 368, Loss: 0.0646, Test Loss: 0.0421
# Epoch 369, Loss: 0.1531, Test Loss: 0.0461
# Epoch 370, Loss: 0.0677, Test Loss: 0.0439
# Epoch 371, Loss: 0.0281, Test Loss: 0.0480
# Epoch 372, Loss: 0.0483, Test Loss: 0.0444
# Epoch 373, Loss: 0.0200, Test Loss: 0.0416
# Epoch 374, Loss: 0.0246, Test Loss: 0.0433
# Epoch 375, Loss: 0.0235, Test Loss: 0.0370
# Epoch 376, Loss: 0.0259, Test Loss: 0.0455
# Epoch 377, Loss: 0.0584, Test Loss: 0.0478
# Epoch 378, Loss: 0.0508, Test Loss: 0.0474
# Epoch 379, Loss: 0.0394, Test Loss: 0.0448
# Epoch 380, Loss: 0.0525, Test Loss: 0.0426
# Epoch 381, Loss: 0.0361, Test Loss: 0.0417
# Epoch 382, Loss: 0.0180, Test Loss: 0.0389
# Epoch 383, Loss: 0.0146, Test Loss: 0.0365
# Epoch 384, Loss: 0.0245, Test Loss: 0.0377
# Epoch 385, Loss: 0.0451, Test Loss: 0.0442
# Epoch 386, Loss: 0.0156, Test Loss: 0.0376
# Epoch 387, Loss: 0.0315, Test Loss: 0.0394
# Epoch 388, Loss: 0.0372, Test Loss: 0.0367
# Epoch 389, Loss: 0.0233, Test Loss: 0.0383
# Epoch 390, Loss: 0.0147, Test Loss: 0.0368
# Epoch 391, Loss: 0.0311, Test Loss: 0.0356
# Epoch 392, Loss: 0.0796, Test Loss: 0.0474
# Epoch 393, Loss: 0.0388, Test Loss: 0.0459
# Epoch 394, Loss: 0.0471, Test Loss: 0.0489
# Epoch 395, Loss: 0.0247, Test Loss: 0.0377
# Epoch 396, Loss: 0.0307, Test Loss: 0.0417
# Epoch 397, Loss: 0.0169, Test Loss: 0.0373
# Epoch 398, Loss: 0.0441, Test Loss: 0.0399
# Epoch 399, Loss: 0.0268, Test Loss: 0.0364
# Epoch 400, Loss: 0.0443, Test Loss: 0.0361
# Epoch 401, Loss: 0.0343, Test Loss: 0.0362
# Epoch 402, Loss: 0.0248, Test Loss: 0.0358
# Epoch 403, Loss: 0.0693, Test Loss: 0.0396
# Epoch 404, Loss: 0.0741, Test Loss: 0.0408
# Epoch 405, Loss: 0.0104, Test Loss: 0.0369
# Epoch 406, Loss: 0.0410, Test Loss: 0.0367
# Epoch 407, Loss: 0.0311, Test Loss: 0.0433
# Epoch 408, Loss: 0.0532, Test Loss: 0.0480
# Epoch 409, Loss: 0.0812, Test Loss: 0.0565
# Epoch 410, Loss: 0.0613, Test Loss: 0.0429
# Epoch 411, Loss: 0.0594, Test Loss: 0.0470
# Epoch 412, Loss: 0.0437, Test Loss: 0.0422
# Epoch 413, Loss: 0.0292, Test Loss: 0.0380
# Epoch 414, Loss: 0.0207, Test Loss: 0.0367
# Epoch 415, Loss: 0.0124, Test Loss: 0.0368
# Epoch 416, Loss: 0.0254, Test Loss: 0.0396
# Epoch 417, Loss: 0.0356, Test Loss: 0.0344
# Epoch 418, Loss: 0.0213, Test Loss: 0.0342
# Epoch 419, Loss: 0.0494, Test Loss: 0.0401
# Epoch 420, Loss: 0.0435, Test Loss: 0.0463
# Epoch 421, Loss: 0.0365, Test Loss: 0.0388
# Epoch 422, Loss: 0.0683, Test Loss: 0.0412
# Epoch 423, Loss: 0.1205, Test Loss: 0.0450
# Epoch 424, Loss: 0.0742, Test Loss: 0.0448
# Epoch 425, Loss: 0.0289, Test Loss: 0.0385
# Epoch 426, Loss: 0.0172, Test Loss: 0.0365
# Epoch 427, Loss: 0.0555, Test Loss: 0.0367
# Epoch 428, Loss: 0.0143, Test Loss: 0.0364
# Epoch 429, Loss: 0.0238, Test Loss: 0.0423
# Epoch 430, Loss: 0.0215, Test Loss: 0.0373
# Epoch 431, Loss: 0.0335, Test Loss: 0.0368
# Epoch 432, Loss: 0.0321, Test Loss: 0.0396
# Epoch 433, Loss: 0.0122, Test Loss: 0.0390
# Epoch 434, Loss: 0.0374, Test Loss: 0.0402
# Epoch 435, Loss: 0.0300, Test Loss: 0.0386
# Epoch 436, Loss: 0.0470, Test Loss: 0.0432
# Epoch 437, Loss: 0.0365, Test Loss: 0.0420
# Epoch 438, Loss: 0.0611, Test Loss: 0.0468
# Epoch 439, Loss: 0.0408, Test Loss: 0.0469
# Epoch 440, Loss: 0.0622, Test Loss: 0.0458
# Epoch 441, Loss: 0.0494, Test Loss: 0.0407
# Epoch 442, Loss: 0.0454, Test Loss: 0.0445
# Epoch 443, Loss: 0.0548, Test Loss: 0.0474
# Epoch 444, Loss: 0.0471, Test Loss: 0.0411
# Epoch 445, Loss: 0.0289, Test Loss: 0.0371
# Epoch 446, Loss: 0.0158, Test Loss: 0.0374
# Epoch 447, Loss: 0.0420, Test Loss: 0.0360
# Epoch 448, Loss: 0.0266, Test Loss: 0.0336
# Epoch 449, Loss: 0.0473, Test Loss: 0.0459
# Epoch 450, Loss: 0.0214, Test Loss: 0.0353
# Epoch 451, Loss: 0.0697, Test Loss: 0.0419
# Epoch 452, Loss: 0.0460, Test Loss: 0.0360
# Epoch 453, Loss: 0.0108, Test Loss: 0.0352
# Epoch 454, Loss: 0.0723, Test Loss: 0.0429
# Epoch 455, Loss: 0.0327, Test Loss: 0.0371
# Epoch 456, Loss: 0.0484, Test Loss: 0.0421
# Epoch 457, Loss: 0.0228, Test Loss: 0.0377
# Epoch 458, Loss: 0.0421, Test Loss: 0.0405
# Epoch 459, Loss: 0.0718, Test Loss: 0.0434
# Epoch 460, Loss: 0.0666, Test Loss: 0.0470
# Epoch 461, Loss: 0.0498, Test Loss: 0.0512
# Epoch 462, Loss: 0.0116, Test Loss: 0.0354
# Epoch 463, Loss: 0.1006, Test Loss: 0.0435
# Epoch 464, Loss: 0.0194, Test Loss: 0.0396
# Epoch 465, Loss: 0.0274, Test Loss: 0.0421
# Epoch 466, Loss: 0.0376, Test Loss: 0.0398
# Epoch 467, Loss: 0.0587, Test Loss: 0.0498
# Epoch 468, Loss: 0.0363, Test Loss: 0.0426
# Epoch 469, Loss: 0.0265, Test Loss: 0.0379
# Epoch 470, Loss: 0.0206, Test Loss: 0.0353
# Epoch 471, Loss: 0.0122, Test Loss: 0.0349
# Epoch 472, Loss: 0.0216, Test Loss: 0.0338
# Epoch 473, Loss: 0.0356, Test Loss: 0.0338
# Epoch 474, Loss: 0.0406, Test Loss: 0.0481
# Epoch 475, Loss: 0.0486, Test Loss: 0.0407
# Epoch 476, Loss: 0.0174, Test Loss: 0.0374
# Epoch 477, Loss: 0.0799, Test Loss: 0.0437
# Epoch 478, Loss: 0.0403, Test Loss: 0.0411
# Epoch 479, Loss: 0.0173, Test Loss: 0.0380
# Epoch 480, Loss: 0.0609, Test Loss: 0.0339
# Epoch 481, Loss: 0.0292, Test Loss: 0.0381
# Epoch 482, Loss: 0.0400, Test Loss: 0.0431
# Epoch 483, Loss: 0.0274, Test Loss: 0.0361
# Epoch 484, Loss: 0.0288, Test Loss: 0.0366
# Epoch 485, Loss: 0.0251, Test Loss: 0.0383
# Epoch 486, Loss: 0.0390, Test Loss: 0.0416
# Epoch 487, Loss: 0.0340, Test Loss: 0.0381
# Epoch 488, Loss: 0.0433, Test Loss: 0.0526
# Epoch 489, Loss: 0.0241, Test Loss: 0.0404
# Epoch 490, Loss: 0.0166, Test Loss: 0.0351
# Epoch 491, Loss: 0.0240, Test Loss: 0.0330
# Epoch 492, Loss: 0.0265, Test Loss: 0.0384
# Epoch 493, Loss: 0.0073, Test Loss: 0.0337
# Epoch 494, Loss: 0.0358, Test Loss: 0.0398
# Epoch 495, Loss: 0.0118, Test Loss: 0.0333
# Epoch 496, Loss: 0.0370, Test Loss: 0.0392
# Epoch 497, Loss: 0.0227, Test Loss: 0.0389
# Epoch 498, Loss: 0.0310, Test Loss: 0.0363
# Epoch 499, Loss: 0.0287, Test Loss: 0.0366
# Epoch 500, Loss: 0.0306, Test Loss: 0.0343
# Epoch 501, Loss: 0.0364, Test Loss: 0.0371
# Epoch 502, Loss: 0.0871, Test Loss: 0.0471
# Epoch 503, Loss: 0.0326, Test Loss: 0.0384
# Epoch 504, Loss: 0.0381, Test Loss: 0.0439
# Epoch 505, Loss: 0.0303, Test Loss: 0.0445
# Epoch 506, Loss: 0.0357, Test Loss: 0.0433
# Epoch 507, Loss: 0.0179, Test Loss: 0.0346
# Epoch 508, Loss: 0.0211, Test Loss: 0.0320
# Epoch 509, Loss: 0.0056, Test Loss: 0.0309
# Epoch 510, Loss: 0.0293, Test Loss: 0.0396
# Epoch 511, Loss: 0.0617, Test Loss: 0.0443
# Epoch 512, Loss: 0.0157, Test Loss: 0.0374
# Epoch 513, Loss: 0.0294, Test Loss: 0.0444
# Epoch 514, Loss: 0.0387, Test Loss: 0.0364
# Epoch 515, Loss: 0.0746, Test Loss: 0.0493
# Epoch 516, Loss: 0.0332, Test Loss: 0.0385
# Epoch 517, Loss: 0.0295, Test Loss: 0.0357
# Epoch 518, Loss: 0.0737, Test Loss: 0.0412
# Epoch 519, Loss: 0.0313, Test Loss: 0.0394
# Epoch 520, Loss: 0.0268, Test Loss: 0.0360
# Epoch 521, Loss: 0.0589, Test Loss: 0.0520
# Epoch 522, Loss: 0.0270, Test Loss: 0.0400
# Epoch 523, Loss: 0.0263, Test Loss: 0.0359
# Epoch 524, Loss: 0.0750, Test Loss: 0.0447
# Epoch 525, Loss: 0.0203, Test Loss: 0.0335
# Epoch 526, Loss: 0.0152, Test Loss: 0.0316
# Epoch 527, Loss: 0.0399, Test Loss: 0.0319
# Epoch 528, Loss: 0.0214, Test Loss: 0.0370
# Epoch 529, Loss: 0.0317, Test Loss: 0.0398
# Epoch 530, Loss: 0.0207, Test Loss: 0.0351
# Epoch 531, Loss: 0.0293, Test Loss: 0.0368
# Epoch 532, Loss: 0.0884, Test Loss: 0.0491
# Epoch 533, Loss: 0.0564, Test Loss: 0.0460
# Epoch 534, Loss: 0.0235, Test Loss: 0.0342
# Epoch 535, Loss: 0.0181, Test Loss: 0.0350
# Epoch 536, Loss: 0.0206, Test Loss: 0.0348
# Epoch 537, Loss: 0.0170, Test Loss: 0.0346
# Epoch 538, Loss: 0.0516, Test Loss: 0.0362
# Epoch 539, Loss: 0.0522, Test Loss: 0.0375
# Epoch 540, Loss: 0.0248, Test Loss: 0.0368
# Epoch 541, Loss: 0.0310, Test Loss: 0.0352
# Epoch 542, Loss: 0.0702, Test Loss: 0.0446
# Epoch 543, Loss: 0.0357, Test Loss: 0.0370
# Epoch 544, Loss: 0.0240, Test Loss: 0.0353
# Epoch 545, Loss: 0.0316, Test Loss: 0.0369
# Epoch 546, Loss: 0.0303, Test Loss: 0.0386
# Epoch 547, Loss: 0.0190, Test Loss: 0.0340
# Epoch 548, Loss: 0.0247, Test Loss: 0.0336
# Epoch 549, Loss: 0.0228, Test Loss: 0.0324
# Epoch 550, Loss: 0.0324, Test Loss: 0.0352
# Epoch 551, Loss: 0.0512, Test Loss: 0.0533
# Epoch 552, Loss: 0.0533, Test Loss: 0.0465
# Epoch 553, Loss: 0.0369, Test Loss: 0.0388
# Epoch 554, Loss: 0.0389, Test Loss: 0.0400
# Epoch 555, Loss: 0.0339, Test Loss: 0.0430
# Epoch 556, Loss: 0.0399, Test Loss: 0.0324
# Epoch 557, Loss: 0.0187, Test Loss: 0.0351
# Epoch 558, Loss: 0.0175, Test Loss: 0.0347
# Epoch 559, Loss: 0.0411, Test Loss: 0.0428
# Epoch 560, Loss: 0.0209, Test Loss: 0.0307
# Epoch 561, Loss: 0.0203, Test Loss: 0.0318
# Epoch 562, Loss: 0.0177, Test Loss: 0.0322
# Epoch 563, Loss: 0.0542, Test Loss: 0.0394
# Epoch 564, Loss: 0.0138, Test Loss: 0.0324
# Epoch 565, Loss: 0.0572, Test Loss: 0.0367
# Epoch 566, Loss: 0.0496, Test Loss: 0.0327
# Epoch 567, Loss: 0.0122, Test Loss: 0.0331
# Epoch 568, Loss: 0.0433, Test Loss: 0.0433
# Epoch 569, Loss: 0.0353, Test Loss: 0.0360
# Epoch 570, Loss: 0.0223, Test Loss: 0.0366
# Epoch 571, Loss: 0.0366, Test Loss: 0.0370
# Epoch 572, Loss: 0.0975, Test Loss: 0.0422
# Epoch 573, Loss: 0.0498, Test Loss: 0.0374
# Epoch 574, Loss: 0.0405, Test Loss: 0.0322
# Epoch 575, Loss: 0.0420, Test Loss: 0.0380
# Epoch 576, Loss: 0.0205, Test Loss: 0.0333
# Epoch 577, Loss: 0.0157, Test Loss: 0.0346
# Epoch 578, Loss: 0.0204, Test Loss: 0.0348
# Epoch 579, Loss: 0.0125, Test Loss: 0.0310
# Epoch 580, Loss: 0.0263, Test Loss: 0.0305
# Epoch 581, Loss: 0.0232, Test Loss: 0.0307
# Epoch 582, Loss: 0.0718, Test Loss: 0.0374
# Epoch 583, Loss: 0.0181, Test Loss: 0.0333
# Epoch 584, Loss: 0.0621, Test Loss: 0.0404
# Epoch 585, Loss: 0.0535, Test Loss: 0.0412
# Epoch 586, Loss: 0.0265, Test Loss: 0.0365
# Epoch 587, Loss: 0.0181, Test Loss: 0.0305
# Epoch 588, Loss: 0.0269, Test Loss: 0.0296
# Epoch 589, Loss: 0.0258, Test Loss: 0.0352
# Epoch 590, Loss: 0.0768, Test Loss: 0.0435
# Epoch 591, Loss: 0.0158, Test Loss: 0.0327
# Epoch 592, Loss: 0.0602, Test Loss: 0.0347
# Epoch 593, Loss: 0.0735, Test Loss: 0.0466
# Epoch 594, Loss: 0.0145, Test Loss: 0.0343
# Epoch 595, Loss: 0.0180, Test Loss: 0.0295
# Epoch 596, Loss: 0.0175, Test Loss: 0.0297
# Epoch 597, Loss: 0.0339, Test Loss: 0.0398
# Epoch 598, Loss: 0.0274, Test Loss: 0.0340
# Epoch 599, Loss: 0.0339, Test Loss: 0.0293
# Epoch 600, Loss: 0.0278, Test Loss: 0.0283
# Epoch 601, Loss: 0.0444, Test Loss: 0.0345
# Epoch 602, Loss: 0.0299, Test Loss: 0.0402
# Epoch 603, Loss: 0.0173, Test Loss: 0.0296
# Epoch 604, Loss: 0.0203, Test Loss: 0.0321
# Epoch 605, Loss: 0.0335, Test Loss: 0.0396
# Epoch 606, Loss: 0.0170, Test Loss: 0.0302
# Epoch 607, Loss: 0.0226, Test Loss: 0.0335
# Epoch 608, Loss: 0.0212, Test Loss: 0.0299
# Epoch 609, Loss: 0.0208, Test Loss: 0.0301
# Epoch 610, Loss: 0.0498, Test Loss: 0.0339
# Epoch 611, Loss: 0.0146, Test Loss: 0.0300
# Epoch 612, Loss: 0.0179, Test Loss: 0.0276
# Epoch 613, Loss: 0.0219, Test Loss: 0.0312
# Epoch 614, Loss: 0.0358, Test Loss: 0.0312
# Epoch 615, Loss: 0.0577, Test Loss: 0.0555
# Epoch 616, Loss: 0.0362, Test Loss: 0.0354
# Epoch 617, Loss: 0.0142, Test Loss: 0.0294
# Epoch 618, Loss: 0.0140, Test Loss: 0.0271
# Epoch 619, Loss: 0.0111, Test Loss: 0.0275
# Epoch 620, Loss: 0.0506, Test Loss: 0.0342
# Epoch 621, Loss: 0.0683, Test Loss: 0.0396
# Epoch 622, Loss: 0.0149, Test Loss: 0.0287
# Epoch 623, Loss: 0.0128, Test Loss: 0.0257
# Epoch 624, Loss: 0.0237, Test Loss: 0.0281
# Epoch 625, Loss: 0.0178, Test Loss: 0.0262
# Epoch 626, Loss: 0.0134, Test Loss: 0.0260
# Epoch 627, Loss: 0.0133, Test Loss: 0.0253
# Epoch 628, Loss: 0.0078, Test Loss: 0.0259
# Epoch 629, Loss: 0.0318, Test Loss: 0.0279
# Epoch 630, Loss: 0.0153, Test Loss: 0.0267
# Epoch 631, Loss: 0.0213, Test Loss: 0.0378
# Epoch 632, Loss: 0.0170, Test Loss: 0.0296
# Epoch 633, Loss: 0.0246, Test Loss: 0.0350
# Epoch 634, Loss: 0.0178, Test Loss: 0.0301
# Epoch 635, Loss: 0.0224, Test Loss: 0.0311
# Epoch 636, Loss: 0.0345, Test Loss: 0.0311
# Epoch 637, Loss: 0.0248, Test Loss: 0.0294
# Epoch 638, Loss: 0.0108, Test Loss: 0.0286
# Epoch 639, Loss: 0.0129, Test Loss: 0.0258
# Epoch 640, Loss: 0.0310, Test Loss: 0.0387
# Epoch 641, Loss: 0.0328, Test Loss: 0.0293
# Epoch 642, Loss: 0.0276, Test Loss: 0.0335
# Epoch 643, Loss: 0.0125, Test Loss: 0.0276
# Epoch 644, Loss: 0.0187, Test Loss: 0.0273
# Epoch 645, Loss: 0.0275, Test Loss: 0.0331
# Epoch 646, Loss: 0.0134, Test Loss: 0.0259
# Epoch 647, Loss: 0.0123, Test Loss: 0.0258
# Epoch 648, Loss: 0.0247, Test Loss: 0.0279
# Epoch 649, Loss: 0.0153, Test Loss: 0.0273
# Epoch 650, Loss: 0.0406, Test Loss: 0.0404
# Epoch 651, Loss: 0.0446, Test Loss: 0.0505
# Epoch 652, Loss: 0.0216, Test Loss: 0.0335
# Epoch 653, Loss: 0.0251, Test Loss: 0.0296
# Epoch 654, Loss: 0.0187, Test Loss: 0.0267
# Epoch 655, Loss: 0.0664, Test Loss: 0.0307
# Epoch 656, Loss: 0.0184, Test Loss: 0.0283
# Epoch 657, Loss: 0.0321, Test Loss: 0.0309
# Epoch 658, Loss: 0.0310, Test Loss: 0.0339
# Epoch 659, Loss: 0.0253, Test Loss: 0.0303
# Epoch 660, Loss: 0.0224, Test Loss: 0.0280
# Epoch 661, Loss: 0.0145, Test Loss: 0.0262
# Epoch 662, Loss: 0.0138, Test Loss: 0.0243
# Epoch 663, Loss: 0.0182, Test Loss: 0.0285
# Epoch 664, Loss: 0.0251, Test Loss: 0.0355
# Epoch 665, Loss: 0.0419, Test Loss: 0.0354
# Epoch 666, Loss: 0.0187, Test Loss: 0.0271
# Epoch 667, Loss: 0.0196, Test Loss: 0.0264
# Epoch 668, Loss: 0.0200, Test Loss: 0.0298
# Epoch 669, Loss: 0.0397, Test Loss: 0.0422
# Epoch 670, Loss: 0.0343, Test Loss: 0.0343
# Epoch 671, Loss: 0.0092, Test Loss: 0.0254
# Epoch 672, Loss: 0.0177, Test Loss: 0.0256
# Epoch 673, Loss: 0.0165, Test Loss: 0.0275
# Epoch 674, Loss: 0.0063, Test Loss: 0.0226
# Epoch 675, Loss: 0.0100, Test Loss: 0.0234
# Epoch 676, Loss: 0.0118, Test Loss: 0.0266
# Epoch 677, Loss: 0.0205, Test Loss: 0.0315
# Epoch 678, Loss: 0.0145, Test Loss: 0.0296
# Epoch 679, Loss: 0.0430, Test Loss: 0.0445
# Epoch 680, Loss: 0.0398, Test Loss: 0.0329
# Epoch 681, Loss: 0.0926, Test Loss: 0.0450
# Epoch 682, Loss: 0.0543, Test Loss: 0.0357
# Epoch 683, Loss: 0.0458, Test Loss: 0.0297
# Epoch 684, Loss: 0.0202, Test Loss: 0.0300
# Epoch 685, Loss: 0.0391, Test Loss: 0.0347
# Epoch 686, Loss: 0.0224, Test Loss: 0.0272
# Epoch 687, Loss: 0.0182, Test Loss: 0.0280
# Epoch 688, Loss: 0.0182, Test Loss: 0.0273
# Epoch 689, Loss: 0.0461, Test Loss: 0.0338
# Epoch 690, Loss: 0.0443, Test Loss: 0.0399
# Epoch 691, Loss: 0.0190, Test Loss: 0.0293
# Epoch 692, Loss: 0.0150, Test Loss: 0.0226
# Epoch 693, Loss: 0.0335, Test Loss: 0.0311
# Epoch 694, Loss: 0.0531, Test Loss: 0.0293
# Epoch 695, Loss: 0.0200, Test Loss: 0.0269
# Epoch 696, Loss: 0.0274, Test Loss: 0.0268
# Epoch 697, Loss: 0.0204, Test Loss: 0.0344
# Epoch 698, Loss: 0.0226, Test Loss: 0.0291
# Epoch 699, Loss: 0.0325, Test Loss: 0.0265
# Epoch 700, Loss: 0.0173, Test Loss: 0.0249
# Epoch 701, Loss: 0.0080, Test Loss: 0.0230
# Epoch 702, Loss: 0.0330, Test Loss: 0.0362
# Epoch 703, Loss: 0.0185, Test Loss: 0.0333
# Epoch 704, Loss: 0.0432, Test Loss: 0.0356
# Epoch 705, Loss: 0.0337, Test Loss: 0.0283
# Epoch 706, Loss: 0.0528, Test Loss: 0.0373
# Epoch 707, Loss: 0.0556, Test Loss: 0.0305
# Epoch 708, Loss: 0.0233, Test Loss: 0.0261
# Epoch 709, Loss: 0.0369, Test Loss: 0.0271
# Epoch 710, Loss: 0.0134, Test Loss: 0.0262
# Epoch 711, Loss: 0.0193, Test Loss: 0.0293
# Epoch 712, Loss: 0.0125, Test Loss: 0.0255
# Epoch 713, Loss: 0.0227, Test Loss: 0.0286
# Epoch 714, Loss: 0.0244, Test Loss: 0.0329
# Epoch 715, Loss: 0.0226, Test Loss: 0.0235
# Epoch 716, Loss: 0.0132, Test Loss: 0.0239
# Epoch 717, Loss: 0.0432, Test Loss: 0.0343
# Epoch 718, Loss: 0.0577, Test Loss: 0.0449
# Epoch 719, Loss: 0.0335, Test Loss: 0.0373
# Epoch 720, Loss: 0.0117, Test Loss: 0.0240
# Epoch 721, Loss: 0.0351, Test Loss: 0.0275
# Epoch 722, Loss: 0.0196, Test Loss: 0.0273
# Epoch 723, Loss: 0.0190, Test Loss: 0.0238
# Epoch 724, Loss: 0.0268, Test Loss: 0.0356
# Epoch 725, Loss: 0.0400, Test Loss: 0.0472
# Epoch 726, Loss: 0.0185, Test Loss: 0.0258
# Epoch 727, Loss: 0.0144, Test Loss: 0.0237
# Epoch 728, Loss: 0.0446, Test Loss: 0.0309
# Epoch 729, Loss: 0.0239, Test Loss: 0.0285
# Epoch 730, Loss: 0.0192, Test Loss: 0.0263
# Epoch 731, Loss: 0.0171, Test Loss: 0.0303
# Epoch 732, Loss: 0.0203, Test Loss: 0.0262
# Epoch 733, Loss: 0.0112, Test Loss: 0.0234
# Epoch 734, Loss: 0.0250, Test Loss: 0.0281
# Epoch 735, Loss: 0.0132, Test Loss: 0.0244
# Epoch 736, Loss: 0.0097, Test Loss: 0.0242
# Epoch 737, Loss: 0.0281, Test Loss: 0.0345
# Epoch 738, Loss: 0.0122, Test Loss: 0.0233
# Epoch 739, Loss: 0.0188, Test Loss: 0.0242
# Epoch 740, Loss: 0.0138, Test Loss: 0.0246
# Epoch 741, Loss: 0.0092, Test Loss: 0.0231
# Epoch 742, Loss: 0.0124, Test Loss: 0.0230
# Epoch 743, Loss: 0.0135, Test Loss: 0.0251
# Epoch 744, Loss: 0.0454, Test Loss: 0.0449
# Epoch 745, Loss: 0.0271, Test Loss: 0.0318
# Epoch 746, Loss: 0.0225, Test Loss: 0.0310
# Epoch 747, Loss: 0.0492, Test Loss: 0.0356
# Epoch 748, Loss: 0.0244, Test Loss: 0.0271
# Epoch 749, Loss: 0.0256, Test Loss: 0.0288
# Epoch 750, Loss: 0.0267, Test Loss: 0.0250
# Epoch 751, Loss: 0.0747, Test Loss: 0.0310
# Epoch 752, Loss: 0.0482, Test Loss: 0.0318
# Epoch 753, Loss: 0.0226, Test Loss: 0.0264
# Epoch 754, Loss: 0.0188, Test Loss: 0.0230
# Epoch 755, Loss: 0.0362, Test Loss: 0.0272
# Epoch 756, Loss: 0.0161, Test Loss: 0.0234
# Epoch 757, Loss: 0.0101, Test Loss: 0.0235
# Epoch 758, Loss: 0.0185, Test Loss: 0.0224
# Epoch 759, Loss: 0.0102, Test Loss: 0.0244
# Epoch 760, Loss: 0.0408, Test Loss: 0.0415
# Epoch 761, Loss: 0.0526, Test Loss: 0.0358
# Epoch 762, Loss: 0.0258, Test Loss: 0.0321
# Epoch 763, Loss: 0.0275, Test Loss: 0.0269
# Epoch 764, Loss: 0.0220, Test Loss: 0.0241
# Epoch 765, Loss: 0.0180, Test Loss: 0.0235
# Epoch 766, Loss: 0.0256, Test Loss: 0.0264
# Epoch 767, Loss: 0.0276, Test Loss: 0.0334
# Epoch 768, Loss: 0.0146, Test Loss: 0.0233
# Epoch 769, Loss: 0.0112, Test Loss: 0.0228
# Epoch 770, Loss: 0.0151, Test Loss: 0.0228
# Epoch 771, Loss: 0.0143, Test Loss: 0.0223
# Epoch 772, Loss: 0.0292, Test Loss: 0.0268
# Epoch 773, Loss: 0.0202, Test Loss: 0.0248
# Epoch 774, Loss: 0.0108, Test Loss: 0.0233
# Epoch 775, Loss: 0.0119, Test Loss: 0.0212
# Epoch 776, Loss: 0.0184, Test Loss: 0.0319
# Epoch 777, Loss: 0.0254, Test Loss: 0.0249
# Epoch 778, Loss: 0.0269, Test Loss: 0.0285
# Epoch 779, Loss: 0.0112, Test Loss: 0.0242
# Epoch 780, Loss: 0.0109, Test Loss: 0.0216
# Epoch 781, Loss: 0.0231, Test Loss: 0.0273
# Epoch 782, Loss: 0.0244, Test Loss: 0.0236
# Epoch 783, Loss: 0.0125, Test Loss: 0.0271
# Epoch 784, Loss: 0.0294, Test Loss: 0.0362
# Epoch 785, Loss: 0.0313, Test Loss: 0.0307
# Epoch 786, Loss: 0.0217, Test Loss: 0.0246
# Epoch 787, Loss: 0.0141, Test Loss: 0.0221
# Epoch 788, Loss: 0.0513, Test Loss: 0.0297
# Epoch 789, Loss: 0.0175, Test Loss: 0.0233
# Epoch 790, Loss: 0.0330, Test Loss: 0.0284
# Epoch 791, Loss: 0.0188, Test Loss: 0.0267
# Epoch 792, Loss: 0.0236, Test Loss: 0.0351
# Epoch 793, Loss: 0.0147, Test Loss: 0.0228
# Epoch 794, Loss: 0.0276, Test Loss: 0.0281
# Epoch 795, Loss: 0.0123, Test Loss: 0.0238
# Epoch 796, Loss: 0.0088, Test Loss: 0.0225
# Epoch 797, Loss: 0.0110, Test Loss: 0.0238
# Epoch 798, Loss: 0.0141, Test Loss: 0.0237
# Epoch 799, Loss: 0.0298, Test Loss: 0.0268
# Epoch 800, Loss: 0.0215, Test Loss: 0.0357
# Epoch 801, Loss: 0.0443, Test Loss: 0.0357
# Epoch 802, Loss: 0.0239, Test Loss: 0.0239
# Epoch 803, Loss: 0.0209, Test Loss: 0.0334
# Epoch 804, Loss: 0.0118, Test Loss: 0.0228
# Epoch 805, Loss: 0.0105, Test Loss: 0.0229
# Epoch 806, Loss: 0.0216, Test Loss: 0.0261
# Epoch 807, Loss: 0.0114, Test Loss: 0.0254
# Epoch 808, Loss: 0.0297, Test Loss: 0.0417
# Epoch 809, Loss: 0.0199, Test Loss: 0.0262
# Epoch 810, Loss: 0.0296, Test Loss: 0.0245
# Epoch 811, Loss: 0.0094, Test Loss: 0.0223
# Epoch 812, Loss: 0.0191, Test Loss: 0.0251
# Epoch 813, Loss: 0.0149, Test Loss: 0.0229
# Epoch 814, Loss: 0.0089, Test Loss: 0.0269
# Epoch 815, Loss: 0.0134, Test Loss: 0.0246
# Epoch 816, Loss: 0.0133, Test Loss: 0.0275
# Epoch 817, Loss: 0.0123, Test Loss: 0.0240
# Epoch 818, Loss: 0.0234, Test Loss: 0.0242
# Epoch 819, Loss: 0.0122, Test Loss: 0.0230
# Epoch 820, Loss: 0.0134, Test Loss: 0.0251
# Epoch 821, Loss: 0.0075, Test Loss: 0.0216
# Epoch 822, Loss: 0.0199, Test Loss: 0.0257
# Epoch 823, Loss: 0.0219, Test Loss: 0.0241
# Epoch 824, Loss: 0.0134, Test Loss: 0.0241
# Epoch 825, Loss: 0.0091, Test Loss: 0.0210
# Epoch 826, Loss: 0.0135, Test Loss: 0.0249
# Epoch 827, Loss: 0.0239, Test Loss: 0.0270
# Epoch 828, Loss: 0.0148, Test Loss: 0.0257
# Epoch 829, Loss: 0.0259, Test Loss: 0.0271
# Epoch 830, Loss: 0.0235, Test Loss: 0.0270
# Epoch 831, Loss: 0.0173, Test Loss: 0.0255
# Epoch 832, Loss: 0.0148, Test Loss: 0.0224
# Epoch 833, Loss: 0.0255, Test Loss: 0.0314
# Epoch 834, Loss: 0.0236, Test Loss: 0.0354
# Epoch 835, Loss: 0.0217, Test Loss: 0.0239
# Epoch 836, Loss: 0.0195, Test Loss: 0.0256
# Epoch 837, Loss: 0.0148, Test Loss: 0.0229
# Epoch 838, Loss: 0.0095, Test Loss: 0.0238
# Epoch 839, Loss: 0.0112, Test Loss: 0.0215
# Epoch 840, Loss: 0.0129, Test Loss: 0.0230
# Epoch 841, Loss: 0.0357, Test Loss: 0.0274
# Epoch 842, Loss: 0.0667, Test Loss: 0.0407
# Epoch 843, Loss: 0.0223, Test Loss: 0.0294
# Epoch 844, Loss: 0.0083, Test Loss: 0.0228
# Epoch 845, Loss: 0.0121, Test Loss: 0.0284
# Epoch 846, Loss: 0.0274, Test Loss: 0.0271
# Epoch 847, Loss: 0.0251, Test Loss: 0.0246
# Epoch 848, Loss: 0.0283, Test Loss: 0.0294
# Epoch 849, Loss: 0.0220, Test Loss: 0.0229
# Epoch 850, Loss: 0.0308, Test Loss: 0.0248
# Epoch 851, Loss: 0.0294, Test Loss: 0.0319
# Epoch 852, Loss: 0.0634, Test Loss: 0.0350
# Epoch 853, Loss: 0.0143, Test Loss: 0.0260
# Epoch 854, Loss: 0.0116, Test Loss: 0.0227
# Epoch 855, Loss: 0.0103, Test Loss: 0.0236
# Epoch 856, Loss: 0.0104, Test Loss: 0.0233
# Epoch 857, Loss: 0.0107, Test Loss: 0.0209
# Epoch 858, Loss: 0.0066, Test Loss: 0.0199
# Epoch 859, Loss: 0.0130, Test Loss: 0.0198
# Epoch 860, Loss: 0.0089, Test Loss: 0.0212
# Epoch 861, Loss: 0.0238, Test Loss: 0.0324
# Epoch 862, Loss: 0.0140, Test Loss: 0.0252
# Epoch 863, Loss: 0.0290, Test Loss: 0.0282
# Epoch 864, Loss: 0.0206, Test Loss: 0.0295
# Epoch 865, Loss: 0.0371, Test Loss: 0.0375
# Epoch 866, Loss: 0.0104, Test Loss: 0.0245
# Epoch 867, Loss: 0.0115, Test Loss: 0.0187
# Epoch 868, Loss: 0.0272, Test Loss: 0.0215
# Epoch 869, Loss: 0.0094, Test Loss: 0.0226
# Epoch 870, Loss: 0.0135, Test Loss: 0.0204
# Epoch 871, Loss: 0.0106, Test Loss: 0.0230
# Epoch 872, Loss: 0.0321, Test Loss: 0.0261
# Epoch 873, Loss: 0.0240, Test Loss: 0.0295
# Epoch 874, Loss: 0.0480, Test Loss: 0.0352
# Epoch 875, Loss: 0.0277, Test Loss: 0.0294
# Epoch 876, Loss: 0.0171, Test Loss: 0.0232
# Epoch 877, Loss: 0.0125, Test Loss: 0.0221
# Epoch 878, Loss: 0.0115, Test Loss: 0.0213
# Epoch 879, Loss: 0.0042, Test Loss: 0.0189
# Epoch 880, Loss: 0.0136, Test Loss: 0.0225
# Epoch 881, Loss: 0.0605, Test Loss: 0.0600
# Epoch 882, Loss: 0.0083, Test Loss: 0.0191
# Epoch 883, Loss: 0.0208, Test Loss: 0.0255
# Epoch 884, Loss: 0.0193, Test Loss: 0.0261
# Epoch 885, Loss: 0.0255, Test Loss: 0.0230
# Epoch 886, Loss: 0.0188, Test Loss: 0.0219
# Epoch 887, Loss: 0.0257, Test Loss: 0.0253
# Epoch 888, Loss: 0.0079, Test Loss: 0.0206
# Epoch 889, Loss: 0.0223, Test Loss: 0.0261
# Epoch 890, Loss: 0.0136, Test Loss: 0.0210
# Epoch 891, Loss: 0.0133, Test Loss: 0.0211
# Epoch 892, Loss: 0.0389, Test Loss: 0.0280
# Epoch 893, Loss: 0.0348, Test Loss: 0.0346
# Epoch 894, Loss: 0.0246, Test Loss: 0.0249
# Epoch 895, Loss: 0.0118, Test Loss: 0.0216
# Epoch 896, Loss: 0.0198, Test Loss: 0.0258
# Epoch 897, Loss: 0.0525, Test Loss: 0.0320
# Epoch 898, Loss: 0.0414, Test Loss: 0.0410
# Epoch 899, Loss: 0.0206, Test Loss: 0.0256
# Epoch 900, Loss: 0.0162, Test Loss: 0.0248
# Epoch 901, Loss: 0.0119, Test Loss: 0.0226
# Epoch 902, Loss: 0.0121, Test Loss: 0.0208
# Epoch 903, Loss: 0.0097, Test Loss: 0.0197
# Epoch 904, Loss: 0.0378, Test Loss: 0.0271
# Epoch 905, Loss: 0.0147, Test Loss: 0.0231
# Epoch 906, Loss: 0.0161, Test Loss: 0.0220
# Epoch 907, Loss: 0.0204, Test Loss: 0.0322
# Epoch 908, Loss: 0.0220, Test Loss: 0.0275
# Epoch 909, Loss: 0.0533, Test Loss: 0.0275
# Epoch 910, Loss: 0.0230, Test Loss: 0.0281
# Epoch 911, Loss: 0.0134, Test Loss: 0.0216
# Epoch 912, Loss: 0.0296, Test Loss: 0.0268
# Epoch 913, Loss: 0.0104, Test Loss: 0.0218
# Epoch 914, Loss: 0.0264, Test Loss: 0.0306
# Epoch 915, Loss: 0.0312, Test Loss: 0.0286
# Epoch 916, Loss: 0.0300, Test Loss: 0.0390
# Epoch 917, Loss: 0.0129, Test Loss: 0.0236
# Epoch 918, Loss: 0.0101, Test Loss: 0.0224
# Epoch 919, Loss: 0.0209, Test Loss: 0.0196
# Epoch 920, Loss: 0.0413, Test Loss: 0.0317
# Epoch 921, Loss: 0.0376, Test Loss: 0.0381
# Epoch 922, Loss: 0.0122, Test Loss: 0.0249
# Epoch 923, Loss: 0.0133, Test Loss: 0.0229
# Epoch 924, Loss: 0.0172, Test Loss: 0.0228
# Epoch 925, Loss: 0.0122, Test Loss: 0.0215
# Epoch 926, Loss: 0.0247, Test Loss: 0.0228
# Epoch 927, Loss: 0.0216, Test Loss: 0.0263
# Epoch 928, Loss: 0.0391, Test Loss: 0.0275
# Epoch 929, Loss: 0.0259, Test Loss: 0.0231
# Epoch 930, Loss: 0.0261, Test Loss: 0.0240
# Epoch 931, Loss: 0.0470, Test Loss: 0.0335
# Epoch 932, Loss: 0.0216, Test Loss: 0.0269
# Epoch 933, Loss: 0.0172, Test Loss: 0.0240
# Epoch 934, Loss: 0.0386, Test Loss: 0.0344
# Epoch 935, Loss: 0.0161, Test Loss: 0.0228
# Epoch 936, Loss: 0.0230, Test Loss: 0.0274
# Epoch 937, Loss: 0.0103, Test Loss: 0.0200
# Epoch 938, Loss: 0.0094, Test Loss: 0.0218
# Epoch 939, Loss: 0.0336, Test Loss: 0.0295
# Epoch 940, Loss: 0.0312, Test Loss: 0.0287
# Epoch 941, Loss: 0.0140, Test Loss: 0.0265
# Epoch 942, Loss: 0.0205, Test Loss: 0.0231
# Epoch 943, Loss: 0.0103, Test Loss: 0.0239
# Epoch 944, Loss: 0.0151, Test Loss: 0.0236
# Epoch 945, Loss: 0.0259, Test Loss: 0.0272
# Epoch 946, Loss: 0.0201, Test Loss: 0.0226
# Epoch 947, Loss: 0.0306, Test Loss: 0.0259
# Epoch 948, Loss: 0.0099, Test Loss: 0.0211
# Epoch 949, Loss: 0.0119, Test Loss: 0.0209
# Epoch 950, Loss: 0.0198, Test Loss: 0.0205
# Epoch 951, Loss: 0.0243, Test Loss: 0.0253
# Epoch 952, Loss: 0.0606, Test Loss: 0.0488
# Epoch 953, Loss: 0.0245, Test Loss: 0.0309
# Epoch 954, Loss: 0.0134, Test Loss: 0.0229
# Epoch 955, Loss: 0.0099, Test Loss: 0.0205
# Epoch 956, Loss: 0.0131, Test Loss: 0.0225
# Epoch 957, Loss: 0.0244, Test Loss: 0.0229
# Epoch 958, Loss: 0.0104, Test Loss: 0.0199
# Epoch 959, Loss: 0.0094, Test Loss: 0.0205
# Epoch 960, Loss: 0.0260, Test Loss: 0.0245
# Epoch 961, Loss: 0.0161, Test Loss: 0.0241
# Epoch 962, Loss: 0.0230, Test Loss: 0.0276
# Epoch 963, Loss: 0.0243, Test Loss: 0.0301
# Epoch 964, Loss: 0.0212, Test Loss: 0.0307
# Epoch 965, Loss: 0.0354, Test Loss: 0.0310
# Epoch 966, Loss: 0.0400, Test Loss: 0.0333
# Epoch 967, Loss: 0.0347, Test Loss: 0.0309
# Epoch 968, Loss: 0.0233, Test Loss: 0.0286
# Epoch 969, Loss: 0.0135, Test Loss: 0.0238
# Epoch 970, Loss: 0.0608, Test Loss: 0.0312
# Epoch 971, Loss: 0.0153, Test Loss: 0.0221
# Epoch 972, Loss: 0.0115, Test Loss: 0.0293
# Epoch 973, Loss: 0.0327, Test Loss: 0.0276
# Epoch 974, Loss: 0.0225, Test Loss: 0.0251
# Epoch 975, Loss: 0.0075, Test Loss: 0.0192
# Epoch 976, Loss: 0.0273, Test Loss: 0.0228
# Epoch 977, Loss: 0.0074, Test Loss: 0.0193
# Epoch 978, Loss: 0.0196, Test Loss: 0.0268
# Epoch 979, Loss: 0.0272, Test Loss: 0.0285
# Epoch 980, Loss: 0.0171, Test Loss: 0.0384
# Epoch 981, Loss: 0.0135, Test Loss: 0.0220
# Epoch 982, Loss: 0.0084, Test Loss: 0.0199
# Epoch 983, Loss: 0.0099, Test Loss: 0.0196
# Epoch 984, Loss: 0.0677, Test Loss: 0.0418
# Epoch 985, Loss: 0.0460, Test Loss: 0.0331
# Epoch 986, Loss: 0.0304, Test Loss: 0.0315
# Epoch 987, Loss: 0.0135, Test Loss: 0.0225
# Epoch 988, Loss: 0.0127, Test Loss: 0.0191
# Epoch 989, Loss: 0.0088, Test Loss: 0.0207
# Epoch 990, Loss: 0.0125, Test Loss: 0.0220
# Epoch 991, Loss: 0.0148, Test Loss: 0.0218
# Epoch 992, Loss: 0.0123, Test Loss: 0.0246
# Epoch 993, Loss: 0.0130, Test Loss: 0.0232
# Epoch 994, Loss: 0.0182, Test Loss: 0.0232
# Epoch 995, Loss: 0.0359, Test Loss: 0.0305
# Epoch 996, Loss: 0.0322, Test Loss: 0.0393
# Epoch 997, Loss: 0.0467, Test Loss: 0.0296
# Epoch 998, Loss: 0.0140, Test Loss: 0.0244
# Epoch 999, Loss: 0.0083, Test Loss: 0.0183
# Epoch 1000, Loss: 0.0220, Test Loss: 0.0291
# Training duration: 35.161325216293335
# [[52.26832     7.18046     0.69592595]
#  [52.26832     7.18046     0.69592595]
#  [52.26912     7.181127    0.6959722 ]
#  [52.27328     7.185415    0.69622684]
#  [52.27662     7.190213    0.69645834]
#  [52.27678     7.190477    0.6964699 ]
#  [52.27934     7.195511    0.6966782 ]
#  [52.28123     7.200455    0.6968634 ]
#  [52.28123     7.200455    0.6968634 ]
#  [52.28175     7.202071    0.6969213 ]]
# [ 4.9959518e+01  6.7808823e+01 -3.1546194e-02 -8.6274109e+01
#   5.1709732e+01  1.0428268e+02  6.8393730e+01  4.2579857e+01
#  -3.6973461e+01  1.0783370e+02]
# [[52.414604    7.3251224   0.43148494]
#  [52.365406    7.235609    0.39913028]
#  [52.403866    7.3524523   0.463853  ]
#  [52.360893    7.3033442   0.53723204]
#  [52.42321     7.1978316   0.43668866]
#  [52.493298    7.264374    0.39864978]
#  [52.38338     7.3691587   0.46350437]
#  [52.37582     7.417351    0.4846299 ]
#  [52.436745    7.311716    0.46393976]
#  [52.383312    7.328445    0.44169787]]

# %%
from itertools import cycle

# Get Traces as lists
*t_orig, = test
*t_recon, = x_recon


# Get Iterator to cycle through
t_orig_cycle = cycle(t_orig)
t_recon_cycle = cycle(t_recon)

# %%
# Cycle and print traces
t1 = next(t_orig_cycle)
t2 = next(t_recon_cycle)

# Print Original Trace (red) and Reconstructed Trace (blue)
plot_two_traces(t1, t2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Test Trace Threads #
#
# - Rounding Thread
# - Signal Noise
# - White Noise

# %%
# Test threads

from threats import *
from trace_plotting import plot_two_traces

first_trace = test[0]

# %%
# Rounding Thread
rounded_trace = remove_non_significant_bits(first_trace, spatial_decimals=1)
plot_two_traces(first_trace, rounded_trace)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Added Signal Noise
noisy_trace = add_signal_noise(first_trace, signal_to_noise_ratio=40)
plot_two_traces(first_trace, noisy_trace)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Added White Noise
noisy_trace2 = add_white_noise(first_trace, spatial_variance=.05)
plot_two_traces(first_trace, noisy_trace2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Remove Points
pts_removed = remove_random_points(first_trace, removal_percentage=.05)
plot_two_traces(first_trace, pts_removed)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Remove Points
pts_removed = replace_non_skeleton_points_with_start_point(first_trace, epsilon=.005)
plot_two_traces(first_trace, pts_removed)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Remove Points
pts_removed = replace_non_skeleton_points_with_path(first_trace, epsilon=.005)
plot_two_traces(first_trace, pts_removed)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Traces Identification #
#
#
# Now we have a trained Autoencoder, which can produce latent representations s.
# To identfy Traces, we produce latent representations for all the traces, which we want to be able to identify.
#
# Then experiment:
#     - for a trace t how close is s(t) to s(a(t)), where a represents an attack
#     - how far away is a different trace

# %%
# Get the representations of own set
s_own_set, rec_own_set = model.run_model(own_set)
s_own_set = s_own_set.numpy()

# %%
# Use Attacks on own_set



# 1. Attack
attack1 =[]
for t in own_set:
    attack1.append(remove_non_significant_bits(t, spatial_decimals=1))
attack1 = np.stack( attack1, axis=0 )    
    
# 2. Attack
attack2 = []
for t in own_set:
    attack2.append(add_signal_noise(t, signal_to_noise_ratio=40))
attack2 = np.stack( attack2, axis=0 ) 
    
# 3. Attack
attack3 = []
for t in own_set:
    attack3.append(add_white_noise(t, spatial_variance=.05))
attack3 = np.stack( attack3, axis=0 )

# 4. Attack
attack4 = []
for t in own_set:
    attack4.append(remove_random_points(t, removal_percentage=.05))
attack4 = np.stack( attack4, axis=0 )

# 5. Attack
attack5 = []
for t in own_set:
    attack5.append(replace_non_skeleton_points_with_start_point(t, epsilon=.005))
attack5 = np.stack( attack5, axis=0 )

# 6. Attack
attack6 = []
for t in own_set:
    attack6.append(replace_non_skeleton_points_with_path(t, epsilon=.005))
attack6 = np.stack( attack6, axis=0 )

# %%
other_set.shape
# Out:
# (2161, 256, 3)

# %%
own_set.shape
# Out:
# (517, 256, 3)

# %%
# Combine with other_set
mixed_set = np.concatenate((other_set, attack1, attack2, attack3, attack4, attack5, attack6), axis=0)

# %%
# Create Label Vector
label_own = np.ones(attack1.shape[0] * 6, dtype=bool)
label_others = np.zeros(other_set.shape[0], dtype=bool)
labels = np.concatenate((label_others, label_own), axis=0)

# %%
def compare_traces(known_trace_encodings, trace_encoding_to_check, tolerance=0.4):
    """
    Compare a list of face encodings against a candidate encoding to see if they match.
    :param known_face_encodings: A list of known face encodings
    :param face_encoding_to_check: A single face encoding to compare against the list
    :param tolerance: How much distance between traces to consider it a match. Lower is more strict. 0.4 is typical best performance.
    :return: A list of True/False values indicating which known_trace_encodings match the trace encoding to check
    """
    ret = True in list(trace_distance(known_trace_encodings, trace_encoding_to_check) <= tolerance)
    return ret


def trace_distance(trace_encodings, trace_to_compare):
    """
    Given a list of encodings, compare them to a known encoding and get a euclidean distance
    for each comparison. The distance tells you how similar the encodings are.
    :param trace_encodings: List of encodings to compare
    :param trace_to_compare: A trace encoding to compare against
    :return: A numpy ndarray with the distance for each trace in the same order as the 'traces' array
    """
    if len(trace_encodings) == 0:
        return np.empty((0))
    
    return np.linalg.norm(trace_encodings - trace_to_compare, axis=1)

# %%
# Run through Test set and get predictions
pred_list = []
for trace in mixed_set:    
    s, _ = model.run_model(np.expand_dims(trace, axis=0))
    prediction = compare_traces(s_own_set, s)
    
    pred_list.append(prediction)
    
predictions = np.asarray(pred_list)

# %%
# Evaluate Predictions
from sklearn.metrics import accuracy_score, f1_score
accuracy = accuracy_score(labels,predictions)
f1 = f1_score(labels, predictions)
print("Accuracy: {:.3f}".format(accuracy))
print("F1 Score: {:.3f}".format(f1))
# Out:
# Accuracy: 0.971
# F1 Score: 0.975

# %% [markdown]
# ## Rounding Thread

# %%
other_set_small = other_set[:len(own_set)]

# %%
# Combine with other_set
mixed_set = np.concatenate((other_set_small, attack1), axis=0)

# %%
# Create Label Vector
label_own = np.ones(attack1.shape[0], dtype=bool)
label_others = np.zeros(other_set_small.shape[0], dtype=bool)
labels = np.concatenate((label_others, label_own), axis=0)

# %%
# Run through Test set and get predictions
pred_list = []
for trace in mixed_set:    
    s, _ = model.run_model(np.expand_dims(trace, axis=0))
    prediction = compare_traces(s_own_set, s)
    
    pred_list.append(prediction)
    
predictions = np.asarray(pred_list)

# %%
# Evaluate Predictions
from sklearn.metrics import accuracy_score, f1_score
accuracy = accuracy_score(labels,predictions)
f1 = f1_score(labels, predictions)
print("Accuracy: {:.3f}".format(accuracy))
print("F1 Score: {:.3f}".format(f1))
# Out:
# Accuracy: 0.974
# F1 Score: 0.973

# %% [markdown]
# ## Signal Noise

# %%
# Combine with other_set
mixed_set = np.concatenate((other_set_small, attack2), axis=0)

# %%
# Run through Test set and get predictions
pred_list = []
for trace in mixed_set:    
    s, _ = model.run_model(np.expand_dims(trace, axis=0))
    prediction = compare_traces(s_own_set, s)
    
    pred_list.append(prediction)
    
predictions = np.asarray(pred_list)

# %%
# Evaluate Predictions
from sklearn.metrics import accuracy_score, f1_score
accuracy = accuracy_score(labels,predictions)
f1 = f1_score(labels, predictions)
print("Accuracy: {:.3f}".format(accuracy))
print("F1 Score: {:.3f}".format(f1))
# Out:
# Accuracy: 0.999
# F1 Score: 0.999

# %% [markdown]
# ## White Noise

# %%
# Combine with other_set
mixed_set = np.concatenate((other_set_small, attack3), axis=0)

# %%
# Run through Test set and get predictions
pred_list = []
for trace in mixed_set:    
    s, _ = model.run_model(np.expand_dims(trace, axis=0))
    prediction = compare_traces(s_own_set, s)
    
    pred_list.append(prediction)
    
predictions = np.asarray(pred_list)

# %%
# Evaluate Predictions
from sklearn.metrics import accuracy_score, f1_score
accuracy = accuracy_score(labels,predictions)
f1 = f1_score(labels, predictions)
print("Accuracy: {:.3f}".format(accuracy))
print("F1 Score: {:.3f}".format(f1))
# Out:
# Accuracy: 0.999
# F1 Score: 0.999

# %% [markdown]
# ## Remove random points

# %%
# Combine with other_set
mixed_set = np.concatenate((other_set_small, attack4), axis=0)

# %%
# Run through Test set and get predictions
pred_list = []
for trace in mixed_set:    
    s, _ = model.run_model(np.expand_dims(trace, axis=0))
    prediction = compare_traces(s_own_set, s)
    
    pred_list.append(prediction)
    
predictions = np.asarray(pred_list)

# %%
# Evaluate Predictions
from sklearn.metrics import accuracy_score, f1_score
accuracy = accuracy_score(labels,predictions)
f1 = f1_score(labels, predictions)
print("Accuracy: {:.3f}".format(accuracy))
print("F1 Score: {:.3f}".format(f1))
# Out:
# Accuracy: 0.996
# F1 Score: 0.996

# %% [markdown]
# ## Replace non skeleton points with start point

# %%
# Combine with other_set
mixed_set = np.concatenate((other_set_small, attack5), axis=0)

# %%
# Run through Test set and get predictions
pred_list = []
for trace in mixed_set:    
    s, _ = model.run_model(np.expand_dims(trace, axis=0))
    prediction = compare_traces(s_own_set, s)
    
    pred_list.append(prediction)
    
predictions = np.asarray(pred_list)

# %%
# Evaluate Predictions
from sklearn.metrics import accuracy_score, f1_score
accuracy = accuracy_score(labels,predictions)
f1 = f1_score(labels, predictions)
print("Accuracy: {:.3f}".format(accuracy))
print("F1 Score: {:.3f}".format(f1))
# Out:
# Accuracy: 0.882
# F1 Score: 0.867

# %% [markdown]
# ## Replace non skeleton points with path

# %%
# Combine with other_set
mixed_set = np.concatenate((other_set_small, attack6), axis=0)

# %%
# Run through Test set and get predictions
pred_list = []
for trace in mixed_set:    
    s, _ = model.run_model(np.expand_dims(trace, axis=0))
    prediction = compare_traces(s_own_set, s)
    
    pred_list.append(prediction)
    
predictions = np.asarray(pred_list)

# %%
# Evaluate Predictions
from sklearn.metrics import accuracy_score, f1_score
accuracy = accuracy_score(labels,predictions)
f1 = f1_score(labels, predictions)
print("Accuracy: {:.3f}".format(accuracy))
print("F1 Score: {:.3f}".format(f1))
# Out:
# Accuracy: 0.998
# F1 Score: 0.998
